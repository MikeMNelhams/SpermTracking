# %%
import json
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
with open(r"C:\Users\richa\Desktop\Univecity projects\MDM3 B\mojo_sperm_tracking_data_bristol\tp49\cover0_0_YOLO_NO_TRACKING_output\centroids_with_meta.json", "r") as read_file:
    data = json.load(read_file)

# %%
x_values = []
y_values = []
frame_values=[]
#Plotting all positions of center of sperm heads for video 0
for i in range(0,len(data["centroids"])): # number of frames
    for j in range(0,len(data["centroids"][i])): #number of sperms in frame
        x_values.append(data["centroids"][i][j]["center"][0])
        y_values.append(data["centroids"][i][j]["center"][1])
        frame_values.append(i)

fig = plt.figure()
ax = plt.axes(projection="3d")
ax.scatter(x_values,y_values,frame_values,color='r',s=1)
ax.set_xlabel('X Axes')
ax.set_ylabel('Y Axes')
ax.set_zlabel('Frame Axes')

plt.show()

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd

X = []
for i in range(0,len(x_values)):
    X.append([x_values[i],y_values[i],frame_values[i]])


# Does the DBSCAN
X = np.asarray(X)
dbscan = DBSCAN(eps=13, min_samples=5)
model = dbscan.fit(X)
labels = model.labels_

# How many clusters?
sample_cores = np.zeros_like(labels, dtype=bool)
sample_cores[dbscan.core_sample_indices_] = True
n_clusters=len(set(labels))-(1 if -1 in labels else 0)
print(n_clusters)
print(labels)
# Out:
# 26
# [ 0  1  2 ... 17 13 21]

# %%
# 13 clusters
cluster_A = [] # 1
cluster_B = [] # 2
cluster_C = [] # 3
cluster_D = [] # 4
cluster_E = [] # 5
cluster_F = [] # 6
cluster_G = [] # 7
cluster_H = [] # 8
cluster_I = [] # 9
cluster_J = [] # 10
cluster_K = [] # 11
cluster_L = [] # 12
cluster_M = [] # 13
cluster_N = [] # 14
cluster_O = [] # 15
cluster_P = [] # 16
cluster_Q = [] # 17 
cluster_R = [] # 18
cluster_S = [] # 19 
cluster_T = [] # 20
cluster_U = [] # 21
cluster_V = [] # 22 
cluster_W = [] # 23 
cluster_X = [] # 24 
cluster_Y = [] # 25 
cluster_Z = [] # 26 

for i in range(0, len(labels)):
    if labels[i] == -1:  # this is the noice data
        cluster_A.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 0:
        cluster_B.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 1:
        cluster_C.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 2:
        cluster_D.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 3:
        cluster_E.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 4:
        cluster_F.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 5:
        cluster_G.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 6:
        cluster_H.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 7:
        cluster_I.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 8:
        cluster_J.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 9:
        cluster_K.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 10:
        cluster_L.append([x_values[i], y_values[i], frame_values[i]])

    elif labels[i] == 11:
        cluster_M.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 12:
        cluster_N.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 13:
        cluster_O.append([x_values[i], y_values[i], frame_values[i]])
        
    elif labels[i] == 14:
        cluster_P.append([x_values[i], y_values[i], frame_values[i]])
                
    elif labels[i] == 15:
        cluster_Q.append([x_values[i], y_values[i], frame_values[i]])
               
    elif labels[i] == 16:
        cluster_R.append([x_values[i], y_values[i], frame_values[i]])
               
    elif labels[i] == 17:
        cluster_S.append([x_values[i], y_values[i], frame_values[i]])
               
    elif labels[i] == 18:
        cluster_T.append([x_values[i], y_values[i], frame_values[i]])
               
    elif labels[i] == 19:
        cluster_U.append([x_values[i], y_values[i], frame_values[i]])
               
    elif labels[i] == 20:
        cluster_V.append([x_values[i], y_values[i], frame_values[i]])
                     
    elif labels[i] == 21:
        cluster_W.append([x_values[i], y_values[i], frame_values[i]])
               
    elif labels[i] == 22:
        cluster_X.append([x_values[i], y_values[i], frame_values[i]])
                
    elif labels[i] == 23:
        cluster_Y.append([x_values[i], y_values[i], frame_values[i]])                        
               
    elif labels[i] == 24:
        cluster_Z.append([x_values[i], y_values[i], frame_values[i]])                         
                         
                         
cluster_A = np.asarray(cluster_A)
cluster_B = np.asarray(cluster_B)
cluster_C = np.asarray(cluster_C)
cluster_D = np.asarray(cluster_D)
cluster_E = np.asarray(cluster_E)
cluster_F = np.asarray(cluster_F)
cluster_G = np.asarray(cluster_G)
cluster_H = np.asarray(cluster_H)
cluster_I = np.asarray(cluster_I)
cluster_J = np.asarray(cluster_J)
cluster_K = np.asarray(cluster_K)
cluster_L = np.asarray(cluster_L)
cluster_M = np.asarray(cluster_M)
cluster_N = np.asarray(cluster_N)
cluster_O = np.asarray(cluster_O)
cluster_P = np.asarray(cluster_P)
cluster_Q = np.asarray(cluster_Q)
cluster_R = np.asarray(cluster_R)
cluster_S = np.asarray(cluster_S)

cluster_T = np.asarray(cluster_T)
cluster_U = np.asarray(cluster_U)
cluster_V = np.asarray(cluster_V)
cluster_W = np.asarray(cluster_W) 
cluster_X = np.asarray(cluster_X)
cluster_Y = np.asarray(cluster_Y)
cluster_Z = np.asarray(cluster_Z) 
                        

fig = plt.figure()
ax = plt.axes(projection="3d")
ax.scatter(cluster_A[:,0], cluster_A[:,1], cluster_A[:,2],color='black',s=1)
ax.scatter(cluster_B[:,0], cluster_B[:,1], cluster_B[:,2],color='peru',s=1)
ax.scatter(cluster_C[:,0], cluster_C[:,1], cluster_C[:,2],color='orange',s=1)
ax.scatter(cluster_D[:,0], cluster_D[:,1], cluster_D[:,2],color='gold',s=1)
ax.scatter(cluster_E[:,0], cluster_E[:,1], cluster_E[:,2],color='palegreen',s=1)
ax.scatter(cluster_F[:,0], cluster_F[:,1], cluster_F[:,2],color='turquoise',s=1)
ax.scatter(cluster_G[:,0], cluster_G[:,1], cluster_G[:,2],color='lime',s=1)
ax.scatter(cluster_H[:,0], cluster_H[:,1], cluster_H[:,2],color='teal',s=1)
ax.scatter(cluster_I[:,0], cluster_I[:,1], cluster_I[:,2],color='blue',s=1)
ax.scatter(cluster_J[:,0], cluster_J[:,1], cluster_J[:,2],color='indigo',s=1)
ax.scatter(cluster_K[:,0], cluster_K[:,1], cluster_K[:,2],color='violet',s=1)
ax.scatter(cluster_L[:,0], cluster_L[:,1], cluster_L[:,2],color='pink',s=1)
ax.scatter(cluster_M[:,0], cluster_M[:,1], cluster_M[:,2],color='darkolivegreen',s=1)
ax.scatter(cluster_N[:,0], cluster_N[:,1], cluster_N[:,2],color='aqua',s=1)
ax.scatter(cluster_O[:,0], cluster_O[:,1], cluster_O[:,2],color='red',s=1)
ax.scatter(cluster_P[:,0], cluster_P[:,1], cluster_P[:,2],color='chocolate',s=1)
ax.scatter(cluster_Q[:,0], cluster_Q[:,1], cluster_Q[:,2],color='coral',s=1)
ax.scatter(cluster_R[:,0], cluster_R[:,1], cluster_R[:,2],color='seagreen',s=1)
ax.scatter(cluster_S[:,0], cluster_S[:,1], cluster_S[:,2],color='gray',s=1)
                         
ax.scatter(cluster_T[:,0], cluster_T[:,1], cluster_T[:,2],color='deeppink',s=1)
ax.scatter(cluster_U[:,0], cluster_U[:,1], cluster_U[:,2],color='lawngreen',s=1)
ax.scatter(cluster_V[:,0], cluster_V[:,1], cluster_V[:,2],color='skyblue',s=1)
ax.scatter(cluster_W[:,0], cluster_W[:,1], cluster_W[:,2],color='steelblue',s=1)
ax.scatter(cluster_X[:,0], cluster_X[:,1], cluster_X[:,2],color='brown',s=1)
ax.scatter(cluster_Y[:,0], cluster_Y[:,1], cluster_Y[:,2],color='salmon',s=1)
ax.scatter(cluster_Z[:,0], cluster_Z[:,1], cluster_Z[:,2],color='teal',s=1)
                         
ax.set_xlabel('X Axes')
ax.set_ylabel('Y Axes')
ax.set_zlabel('Frame Axes')
plt.show()
